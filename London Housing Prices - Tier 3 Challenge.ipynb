# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# 5 rows , 49 columns
# 1 st row!
# 1st Column!
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01       91448.98           50460.23   93284.52   64958.09
# 2 1995-02-01       82202.77           51085.78   93190.17   64787.92
# 3 1995-03-01       79120.70           51268.97   92247.52   64367.49
# 4 1995-04-01       77101.21           53133.51   90762.87   64277.67
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1   71306.57   81671.48  120932.89   69158.16   79885.89  ...   43958.48
# 2   72022.26   81657.56  119508.86   68951.10   80897.07  ...   43925.42
# 3   72015.76   81449.31  120282.21   68712.44   81379.86  ...   44434.87
# 4   72965.63   81124.41  120097.90   68610.05   82188.90  ...   44267.78
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# ...

# %%
properties.describe()
# drop Columns: Unnamed: 34, Unnamed: 37, Unnamed: 47
# Out:
#        Unnamed: 34  Unnamed: 37  Unnamed: 47
# count         0.00         0.00         0.00
# mean           NaN          NaN          NaN
# std            NaN          NaN          NaN
# min            NaN          NaN          NaN
# 25%            NaN          NaN          NaN
# 50%            NaN          NaN          NaN
# 75%            NaN          NaN          NaN
# max            NaN          NaN          NaN

# %%
properties.info()
# Unnamed: 0 contains dates, rest of unnamed columns don't seem to contain anything!
# fix some column names to proper case
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345 entries, 0 to 344
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            344 non-null    datetime64[ns]
#  1   City of London        345 non-null    object
#  2   Barking & Dagenham    345 non-null    object
#  3   Barnet                345 non-null    object
#  4   Bexley                345 non-null    object
#  5   Brent                 345 non-null    object
#  6   Bromley               345 non-null    object
#  7   Camden                345 non-null    object
#  8   Croydon               345 non-null    object
#  9   Ealing                345 non-null    object
#  10  Enfield               345 non-null    object
#  11  Greenwich             345 non-null    object
#  12  Hackney               345 non-null    object
#  13  Hammersmith & Fulham  345 non-null    object
# ...

# %%
np.unique(properties[['Unnamed: 34','Unnamed: 37','Unnamed: 47']].values)
# Out:
# array([nan])

# %%
properties = properties.drop(columns = ['Unnamed: 34','Unnamed: 37','Unnamed: 47'])

# %%
# properties['Unnamed: 0'] = properties['Unnamed: 0'].dt.strftime('%Y-%m')

# %%
properties['Unnamed: 0']
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01       91448.98           50460.23   93284.52   64958.09
# 2 1995-02-01       82202.77           51085.78   93190.17   64787.92
# 3 1995-03-01       79120.70           51268.97   92247.52   64367.49
# 4 1995-04-01       77101.21           53133.51   90762.87   64277.67
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH EAST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000001
# 1   71306.57   81671.48  120932.89   69158.16   79885.89  ...   42076.35
# 2   72022.26   81657.56  119508.86   68951.10   80897.07  ...   42571.99
# 3   72015.76   81449.31  120282.21   68712.44   81379.86  ...   42369.73
# 4   72965.63   81124.41  120097.90   68610.05   82188.90  ...   42095.84
#
#   NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties_transpose = properties.T
properties_transpose = properties_transpose.reset_index()
properties_transpose.columns = properties_transpose.iloc[0]
properties_transpose = properties_transpose[1:]
properties_transpose.head(5)
# Out:
# 0          Unnamed: 0        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001            91448.98            82202.77
# 2  Barking & Dagenham  E09000002            50460.23            51085.78
# 3              Barnet  E09000003            93284.52            93190.17
# 4              Bexley  E09000004            64958.09            64787.92
# 5               Brent  E09000005            71306.57            72022.26
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1            79120.70            77101.21            84409.15
# 2            51268.97            53133.51            53042.25
# 3            92247.52            90762.87            90258.00
# 4            64367.49            64277.67            63997.14
# 5            72015.76            72965.63            73704.05
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1            94900.51           110128.04           112329.44  ...
# ...

# %%
properties_transpose.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 1 to 45
# Columns: 346 entries, Unnamed: 0 to 2023-08-01 00:00:00
# dtypes: object(346)
# memory usage: 121.8+ KB

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties_transpose = properties_transpose.rename(columns={"Unnamed: 0":"Borough"})
properties_transpose = properties_transpose.rename(columns = {properties_transpose.columns[1]:"Area Code"})
properties_transpose.head()
# Out:
# 0             Borough  Area Code 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001            91448.98            82202.77
# 2  Barking & Dagenham  E09000002            50460.23            51085.78
# 3              Barnet  E09000003            93284.52            93190.17
# 4              Bexley  E09000004            64958.09            64787.92
# 5               Brent  E09000005            71306.57            72022.26
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1            79120.70            77101.21            84409.15
# 2            51268.97            53133.51            53042.25
# 3            92247.52            90762.87            90258.00
# 4            64367.49            64277.67            63997.14
# 5            72015.76            72965.63            73704.05
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1            94900.51           110128.04           112329.44  ...
# ...

# %%
properties_transpose['Area Code'].unique()
# Out:
# array(['E09000001', 'E09000002', 'E09000003', 'E09000004', 'E09000005',
#        'E09000006', 'E09000007', 'E09000008', 'E09000009', 'E09000010',
#        'E09000011', 'E09000012', 'E09000013', 'E09000014', 'E09000015',
#        'E09000016', 'E09000017', 'E09000018', 'E09000019', 'E09000020',
#        'E09000021', 'E09000022', 'E09000023', 'E09000024', 'E09000025',
#        'E09000026', 'E09000027', 'E09000028', 'E09000029', 'E09000030',
#        'E09000031', 'E09000032', 'E09000033', 'E13000001', 'E13000002',
#        'E12000001', 'E12000002', 'E12000003', 'E12000004', 'E12000005',
#        'E12000006', 'E12000007', 'E12000008', 'E12000009', 'E92000001'],
#       dtype=object)

# %%
properties_transpose['Area Code'].nunique()
# Out:
# 45

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties_transpose.head(50)
# Out:
# 0                Borough  Area Code 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1         City of London  E09000001            91448.98            82202.77
# 2     Barking & Dagenham  E09000002            50460.23            51085.78
# 3                 Barnet  E09000003            93284.52            93190.17
# 4                 Bexley  E09000004            64958.09            64787.92
# 5                  Brent  E09000005            71306.57            72022.26
# 6                Bromley  E09000006            81671.48            81657.56
# 7                 Camden  E09000007           120932.89           119508.86
# 8                Croydon  E09000008            69158.16            68951.10
# 9                 Ealing  E09000009            79885.89            80897.07
# 10               Enfield  E09000010            72514.69            73155.20
# 11             Greenwich  E09000011            62300.10            60993.27
# ...

# %%
properties_melt = properties_transpose.melt(id_vars = ['Borough','Area Code'])
properties_melt.head(5)
# Out:
#               Borough  Area Code          0    value
# 0      City of London  E09000001 1995-01-01 91448.98
# 1  Barking & Dagenham  E09000002 1995-01-01 50460.23
# 2              Barnet  E09000003 1995-01-01 93284.52
# 3              Bexley  E09000004 1995-01-01 64958.09
# 4               Brent  E09000005 1995-01-01 71306.57

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties_melt = properties_melt.rename(columns = {properties_melt.columns[2]:"Month", properties_melt.columns[3]:"Price"})

# %%
# properties_melt['Month'] =  properties_melt['Month'].dt.strftime('%Y-%b')
properties_melt['Price'] = properties_melt['Price'].astype(float)
properties_melt.head()
# Out:
#               Borough  Area Code      Month    Price
# 0      City of London  E09000001 1995-01-01 91448.98
# 1  Barking & Dagenham  E09000002 1995-01-01 50460.23
# 2              Barnet  E09000003 1995-01-01 93284.52
# 3              Bexley  E09000004 1995-01-01 64958.09
# 4               Brent  E09000005 1995-01-01 71306.57

# %%
properties_melt.info()

# No null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15480 entries, 0 to 15479
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Borough    15480 non-null  object
#  1   Area Code  15480 non-null  object
#  2   Month      15480 non-null  datetime64[ns]
#  3   Price      15480 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 483.9+ KB

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
properties_borough = properties_melt[properties_melt["Area Code"].str.startswith("E09") &  ~properties_melt["Area Code"].str.endswith("00001")]

#Look at boroughs area codes while excluding City of London

# %%
properties_borough["Area Code"].nunique()
# Out:
# 32

# %%
properties_borough.head()
# Out:
#               Borough  Area Code      Month    Price
# 1  Barking & Dagenham  E09000002 1995-01-01 50460.23
# 2              Barnet  E09000003 1995-01-01 93284.52
# 3              Bexley  E09000004 1995-01-01 64958.09
# 4               Brent  E09000005 1995-01-01 71306.57
# 5             Bromley  E09000006 1995-01-01 81671.48

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
barnet = properties_borough[properties_borough["Area Code"].str.endswith("03")]
barnet
# Out:
#       Borough  Area Code      Month     Price
# 2      Barnet  E09000003 1995-01-01  93284.52
# 47     Barnet  E09000003 1995-02-01  93190.17
# 92     Barnet  E09000003 1995-03-01  92247.52
# 137    Barnet  E09000003 1995-04-01  90762.87
# 182    Barnet  E09000003 1995-05-01  90258.00
# ...       ...        ...        ...       ...
# 15257  Barnet  E09000003 2023-04-01 589433.00
# 15302  Barnet  E09000003 2023-05-01 577357.00
# 15347  Barnet  E09000003 2023-06-01 578060.00
# 15392  Barnet  E09000003 2023-07-01 586454.00
# 15437  Barnet  E09000003 2023-08-01 598661.00
#
# [344 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize=(17, 4))
fig.autofmt_xdate()

plt.plot(barnet['Month'].dt.strftime('%Y-%m'),  barnet['Price'])
ax.get_xaxis().set_visible(False)
plt.ylabel("Average Price")
plt.xlabel("Months from 1995 - 2023")
ax.set_title('Average Price for Barnet - E09000003 (Months 1995 - 2023)')
# ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.xlim(0,3)
# plt.axis('off')
plt.show()

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
# barnet['Month'].dt.strftime('%Y')
barnet = barnet.assign(Year = lambda row: row['Month'].dt.strftime('%Y') )

# df = df.assign(Percentage = lambda x: (x['Total_Marks'] /500 * 100))
fig, ax = plt.subplots(figsize=(17, 4))
fig.autofmt_xdate()

plt.plot(barnet['Year'],  barnet['Price'])
ax.get_xaxis().set_visible(False)
plt.ylabel("Average Price")
plt.xlabel("1995 - 2023")
ax.set_title('Average Price for Barnet - E09000003 (1995 - 2023)')
# ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.xlim(0,3)
# plt.axis('off')
plt.show()

# %%
properties_borough = properties_borough.assign(Year = lambda row: row['Month'].dt.strftime('%Y') )
properties_borough.head()
# Out:
#               Borough  Area Code      Month    Price  Year
# 1  Barking & Dagenham  E09000002 1995-01-01 50460.23  1995
# 2              Barnet  E09000003 1995-01-01 93284.52  1995
# 3              Bexley  E09000004 1995-01-01 64958.09  1995
# 4               Brent  E09000005 1995-01-01 71306.57  1995
# 5             Bromley  E09000006 1995-01-01 81671.48  1995

# %%
test_ = properties_borough.groupby(['Borough','Year'])['Price'].mean()
# type(test_)
test_.to_frame()
test_ = test_.reset_index()
test_['Price'] = test_['Price'].astype(float)
test_.head()
# Out:
#               Borough  Year    Price
# 0  Barking & Dagenham  1995 51817.97
# 1  Barking & Dagenham  1996 51718.19
# 2  Barking & Dagenham  1997 55974.26
# 3  Barking & Dagenham  1998 60285.82
# 4  Barking & Dagenham  1999 65320.93

# %%
# suppress scientific notation by setting float_format
# pd.options.display.float_format = '{:.02}'.format
pd.options.display.float_format = '{:.2f}'.format
# pd.reset_option('^display.', silent=True)

test_[(test_["Year"]=='1995') | (test_["Year"]=='2023')]
# test_["Price"].astype(float)
# df_2023 = test_[test_["Year"]=='2023']
df_2023 = df_2023.rename(columns={"Price":"Price_2023"})
# df_1995 = test_[test_["Year"]=='1995']
df_1995 = df_1995.rename(columns={"Price":"Price_1995"})
df_final = df_2023.merge(df_1995, on = 'Borough', suffixes = ('_2023', '_1995'))
df_final["Delta"] = df_final['Price_2023'] - df_final['Price_1995']
df_final["Delta"] = df_final["Delta"].astype(float)

df_final[["Borough","Delta"]]

df_final.sort_values(by="Delta",ascending = False, ignore_index=True)
# Out:
#                  Borough Year_2023  Price_2023 Year_1995  Price_1995  \
# 0   Kensington & Chelsea      2023  1347605.62      1995   192857.26
# 1            Westminster      2023  1002961.12      1995   133689.23
# 2                 Camden      2023   857227.62      1995   120367.43
# 3   Hammersmith & Fulham      2023   780775.88      1995   123238.00
# 4   Richmond upon Thames      2023   755017.88      1995   109892.27
# 5              Islington      2023   701425.62      1995    95555.07
# 6                Hackney      2023   632248.75      1995    66024.48
# 7             Wandsworth      2023   626314.62      1995    88829.08
# 8               Haringey      2023   605221.12      1995    80078.49
# 9                 Barnet      2023   591342.75      1995    91792.54
# 10                Merton      2023   578227.00      1995    80500.75
# 11               Lambeth      2023   550752.50      1995    68105.69
# 12             Southwark      2023   540100.62      1995    64260.05
# ...

# %% [markdown]
# # Question - Which borough of London has seen the greatest average increase in housing prices over the (approximately) two decades covered by the dataset? - Answer is: "Kensington & Chelsea"

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def create_price_ratio(name):
    """ Find the ratio of price increase from 1998 to 2018 for Borough entered """
    a = test_['Price'][(test_["Borough"] == name) & (test_["Year"] == '2018')]
    b =  test_['Price'][(test_["Borough"] == name) & (test_["Year"] == '1998')]
    # print(a)
    a= a.reset_index()
    b = b.reset_index()
    # print(a)
    # print(b)
    c = a/b
    c = c.drop(columns='index',axis=1)
    # print(c)
#     print(name)
#     print(c['Price'].to_string(index=False))
    print('2018 to 1998 ratio for ' + name + ' is : '  ,'\033[1m' +c['Price'].to_string(index=False))

# %%
create_price_ratio('Barnet')
# Out:
# 2018 to 1998 ratio for Barnet is :  4.36

# %%
test_['Borough'].unique()
# Out:
# array(['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley',
#        'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney',
#        'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster'],
#       dtype=object)

# %%
list(map(create_price_ratio, test_['Borough'].unique()))
# Out:
# 2018 to 1998 ratio for Barking & Dagenham is :  4.90
# 2018 to 1998 ratio for Barnet is :  4.36
# 2018 to 1998 ratio for Bexley is :  4.25
# 2018 to 1998 ratio for Brent is :  4.89
# 2018 to 1998 ratio for Bromley is :  4.09
# 2018 to 1998 ratio for Camden is :  4.94
# 2018 to 1998 ratio for Croydon is :  4.20
# 2018 to 1998 ratio for Ealing is :  4.31
# 2018 to 1998 ratio for Enfield is :  4.26
# 2018 to 1998 ratio for Greenwich is :  4.76
# 2018 to 1998 ratio for Hackney is :  6.20
# 2018 to 1998 ratio for Hammersmith & Fulham is :  4.14
# 2018 to 1998 ratio for Haringey is :  5.13
# 2018 to 1998 ratio for Harrow is :  4.06
# 2018 to 1998 ratio for Havering is :  4.33
# 2018 to 1998 ratio for Hillingdon is :  4.20
# 2018 to 1998 ratio for Hounslow is :  3.98
# 2018 to 1998 ratio for Islington is :  4.84
# 2018 to 1998 ratio for Kensington & Chelsea is :  5.08
# 2018 to 1998 ratio for Kingston upon Thames is :  4.27
# 2018 to 1998 ratio for Lambeth is :  4.96
# ...

# %%
'Westminster' in  test_["Borough"].unique()
# test_['Price'][(test_["Borough"] == 'Barnet') & (test_["Year"] == '2018')]
# Out:
# True

# %%
a = test_['Price'][(test_["Borough"] == 'Barnet') & (test_["Year"] == '2018')]
b =  test_['Price'][(test_["Borough"] == 'Barnet') & (test_["Year"] == '1998')]
# print(a)
a= a.reset_index()
b = b.reset_index()
# print(a)
# print(b)
c = a/b
c = c.drop(columns='index',axis=1)
# print(c)
print(c['Price'].to_string(index=False))
# Out:
# 4.36

# %%
a = test_['Price'][(test_["Borough"] == 'Barnet') & (test_["Year"] == '2018')]
b =  test_['Price'][(test_["Borough"] == 'Barnet') & (test_["Year"] == '1998')]
a= a.reset_index()
b = b.reset_index()
print(a.values)
print(b)
print(a/b)
# Out:
#    index     Price
# 0     52 533266.53
#    index     Price
# 0     32 122359.47
#    index  Price
# 0   1.62   4.36

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %%
# From 1995 to 2023 Kensington & Chelsea - have seen the biggest increase in housing prices, an increase of 1,154,848 pounds

# However between 1998 and 2018 the biggest increase of  6.2 was for Hackney (which ranked 7th overall)

# The top 3 Boroughs in terms of average price increase Kensington & Chelsea, Westminster, and Camden are all located in Central London


# Summarize what I have done:
# - After  Loading the data
# - cleaning - drop null columns , transposing to get Boroughs and area codes as key columns with data/price for each month in individual columns
# - using melt to get Borough, and Area codes as main ids with price and date as the value 
# - Renaming columns before and after melt to give more meaningful column names

# - Filter to only London borough area codes while also excluding city of london

# - Visualizing trend for one borough Barnet 

# Finally

# - Looked at delta values for first and last year, identified the solution
# - Created a function to find ratio for price between 2018 and 1998 where one borough can be entered
# - used map function to enter entire list of boroughs to this function to note highest increase
